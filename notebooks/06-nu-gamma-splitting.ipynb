# %% [markdown]
# # 06 — $\nu$–$\gamma$ Temperature Splitting
#
# **PDF reference**: Appendix B, Eq. (B.1)–(B.4)
#
# ## Scope
#
# - $T_\nu \approx T_\gamma \min\{[g_{\star,s}(T_\gamma)/g_{\star,s}(T_{\nu\mathrm{dec}})]^{1/3}, 1\}$ (Eq. B.1)
# - Entropy conservation: $[2T_\gamma^3 + \frac{7}{8} \cdot 4 \cdot \mathcal{I}(m_e/T_\gamma) T_\gamma^3 + \frac{7}{8} \cdot 6 \cdot T_\nu^3] a^3 = \mathrm{const}$ (Eq. B.2)
# - $T_\nu a = \mathrm{const}$ (Eq. B.3)
# - $\mathcal{I}(x)$ integral (Eq. B.4)
# - Solve coupled $T_\gamma$, $T_\nu$ evolution; verify $(4/11)^{1/3}$ asymptotic ratio
