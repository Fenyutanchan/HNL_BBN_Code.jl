# %% [markdown]
# # 04 — Freeze-out Regime
#
# **PDF reference**: §2.1.2, Eq. (2.13)
#
# ## Scope
#
# - Freeze-out temperature $T_\mathrm{fo} \approx \left(\frac{g_H}{\theta^2 c_\alpha G_F^2 x_p m_\mathrm{pl}}\right)^{1/3}_{\mathrm{fo}} \simeq \frac{1\,\mathrm{MeV}}{\theta^{2/3}}$
# - $T_\mathrm{fo}$ vs $\theta$ for several $m_N$ values
# - Crossover with freeze-in regime boundary ($\xi_N = 1$)
