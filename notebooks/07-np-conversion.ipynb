# %% [markdown]
# # 07 — Neutron-Proton Conversion & BBN
#
# **PDF reference**: Appendix C (Eq. C.1–C.3), Appendix D (Eq. D.1–D.6)
#
# ## Scope
#
# ### Appendix C — $n \leftrightarrow p$ conversion rates
# - $\Gamma_{n\to p}^{(\mathrm{SM})} \approx \frac{1}{\tau_n}[1 + \frac{4Q^5}{m_e^5 \lambda_0} \cdot \frac{12+6x+x^2}{x^5}]$ (Eq. C.1)
# - $\Gamma_{p\to n}^{(\mathrm{SM})} \approx e^{-x} \Gamma_{n\to p}^{(\mathrm{SM})}$ (Eq. C.3)
#
# ### Appendix D — BBN physics
# - Neutron/proton number density: Maxwell-Boltzmann (Eq. D.1)
# - Equilibrium ratio $n_n/n_p \approx e^{-Q/T}$ (Eq. D.2)
# - $X_n$ Boltzmann equation (Eq. D.3–D.4)
# - Hubble parameter and $t$–$T$ relation (Eq. D.5–D.6)
# - Solve $X_n(T)$ numerically; verify standard BBN neutron freeze-out
