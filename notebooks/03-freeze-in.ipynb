# %% [markdown]
# # 03 — Freeze-in Regime: Analytical $f_N$
#
# **PDF reference**: §2.1.1, Appendix A, Eq. (2.9)–(2.12)
#
# ## Scope
#
# - Freeze-in integral $f_N(a,p) = \int_0^a \frac{\Gamma_\mathrm{prod}}{H a'} da'$ (Eq. 2.9)
# - Analytical approximation: $f_N \approx \xi_N / [\exp(ap/a_\star T_\star) + 1]$ (Eq. 2.10)
# - $\xi_N$ parameter (Eq. 2.11)
# - Freeze-in bound $\theta^2 \lesssim 1.3 \times 10^{-12} (1\,\mathrm{GeV}/m_N)$ (Eq. 2.12)
# - Appendix A: $F(x, \theta, A)$ integral — analytical form, verify $x \to 0$ and $x \to \infty$ limits
# - Comparison: analytical vs numerical $f_N(a, p)$
