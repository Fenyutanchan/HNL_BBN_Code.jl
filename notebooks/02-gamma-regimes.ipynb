# %% [markdown]
# # 02 — $\gamma_\alpha$ and Freeze-in / Freeze-out Regimes
#
# **PDF reference**: §2.1, Eq. (2.6)–(2.8)
#
# **Reproduces**: Figure 2 — $\gamma_\alpha(T)$ for $m_N = 0.1$ GeV, $x_p \in \{1, 3, 9\}$
#
# ## Scope
#
# - $\gamma_\alpha \equiv \frac{\Gamma_\alpha}{4H} \sin^2 2\theta_\mathrm{eff}$
# - Low-$T$ and high-$T$ asymptotic limits (Eq. 2.7)
# - Peak temperature $T_\mathrm{peak}$ (Eq. 2.8)
# - Freeze-in ($\gamma_\alpha \ll 1$) vs freeze-out ($\gamma_\alpha > 1$) classification
